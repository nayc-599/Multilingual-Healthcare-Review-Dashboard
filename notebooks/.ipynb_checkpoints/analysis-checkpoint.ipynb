# %%
import pandas as pd

# %%
df = pd.read_csv('../data/summary/summary.csv')

# %%
df
# Out:
#    Unnamed: 0.1  Unnamed: 0  topic_id  \
# 0             0           0         1
# 1             1           1         3
# 2             2           2         4
# 3             3           3         7
# 4             4           4        13
# 5             5           5        15
# 6             6           6        17
# 7             7           7        18
# 8             8           8        19
# 9             9           9        99
#
#                                              summary  \
# 0   A patient was forced to pay 400 rubles to pay...
# 1   I am ashamed of the professionalism of the do...
# 2   I've cured a few teeth from Dr. Kurilov Evgen...
# 3   6 r/d gave birth to a 17-year-old house in Lu...
# 4   On November 22, 2015, a gynaecologist said th...
# 5   Vladimir Pood. came with Caries in two teeth,...
# 6   The T.C. Triumphal salon is not recommended f...
# 7   After a sports injury, terrible back pains be...
# 8   A friend of ours died yesterday in ICU, and h...
# ...

# %%
topic_keywords = [
    "Confusing Billing, Closed Doctor Offices, Poor Communication, Long Referral Delays, Misleading Website",
    "Highly Skilled Doctors, Compassionate Nurses, Attentive Care, Professional Leadership, Lifesaving Expertise",
    "Competent Dentists, Painless Procedures, Thorough Explanations, Friendly Staff, Clear Hygiene Guidance",
    "Supportive Midwives, Caring Obstetricians, Clean Maternity Wards, Positive Birth Experience, Attentive Nurses",
    "Delayed Diagnosis, Overcrowded Wards, Poor Sanitation, Unresponsive Staff, Stressful Environment",
    "Poor Dental Quality, Improper Procedures, Expensive Treatment, Multiple Corrective Visits, Painful Follow-Up",
    "High Lens Prices, Limited Selection, Poor Consultant Guidance, Confusing Discounts, Frustrating Ordering Process",
    "Skilled Neurosurgeon, Successful Operation, Proper Post-Op Care, Pain Relief, Positive Recovery",
    "Unreachable Doctors, Poor Communication, Delayed Emergency Care, Inadequate Staff Response, Patient Safety Risk",
    "Limited Pediatric Staff, Delayed Treatment, No Phone Updates, Overcrowded Wards, Poor Management Oversight"
]

df['keywords'] = topic_keywords

# %%
df
# Out:
#    topic_id                                            summary  \
# 0         1   A patient was forced to pay 400 rubles to pay...
# 1         3   I am ashamed of the professionalism of the do...
# 2         4   I've cured a few teeth from Dr. Kurilov Evgen...
# 3         7   6 r/d gave birth to a 17-year-old house in Lu...
# 4        13   On November 22, 2015, a gynaecologist said th...
# 5        15   Vladimir Pood. came with Caries in two teeth,...
# 6        17   The T.C. Triumphal salon is not recommended f...
# 7        18   After a sports injury, terrible back pains be...
# 8        19   A friend of ours died yesterday in ICU, and h...
# 9        99   It's Child Protection Day again, and no one h...
#
#                               representative_reviews  count  positive  \
# 0  Today, at your doctor's address, he came to do...   1621       266
# 1  Good afternoon, I wish to express my great gra...   2507      2455
# ...

# %%
topic_names = [
    "Administration",
    "Medical Teams",
    "Dental Clinic Services",
    "Maternity Care",
    "Pediatric Care",
    "Dental Procedures",
    "Optical Services",
    "Neurosurgery",
    "ICU & Emergency Care",
    "Other"
]

df['topic'] = topic_names

# %%
df
# Out:
#    topic_id                                            summary  \
# 0         1   A patient was forced to pay 400 rubles to pay...
# 1         3   I am ashamed of the professionalism of the do...
# 2         4   I've cured a few teeth from Dr. Kurilov Evgen...
# 3         7   6 r/d gave birth to a 17-year-old house in Lu...
# 4        13   On November 22, 2015, a gynaecologist said th...
# 5        15   Vladimir Pood. came with Caries in two teeth,...
# 6        17   The T.C. Triumphal salon is not recommended f...
# 7        18   After a sports injury, terrible back pains be...
# 8        19   A friend of ours died yesterday in ICU, and h...
# 9        99   It's Child Protection Day again, and no one h...
#
#                               representative_reviews  count  positive  \
# 0  Today, at your doctor's address, he came to do...   1621       266
# 1  Good afternoon, I wish to express my great gra...   2507      2455
# ...

# %%
df.to_csv("summary.csv")
