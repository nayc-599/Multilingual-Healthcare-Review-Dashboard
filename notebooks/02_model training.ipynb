# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN
from collections import defaultdict
from gensim import corpora
from gensim.models import LdaModel
from gensim.models import CoherenceModel
from transformers import MarianMTModel, MarianTokenizer
from tqdm import tqdm
from transformers import pipeline
import itertools
import torch

# %%
df = pd.read_csv("../data/sample/sample_processed_reviews.csv")
df
# Out:
#                                                 reviews  sentiment  \
# 0     Огромная благодарность Анне Геннадьевне Рябцев...          1
# 1     Казахстан, г. Алматы, тёща ходила на Серагем 2...          0
# 2     Пусть будет немного странно, но хотела бы выра...          1
# 3     Мне очень понравилось отношение к пациенту. Пр...          1
# 4     Ну, лично я считаю, что для бесплатной консуль...          1
# ...                                                 ...        ...
# 9995  Были 02 февраля в клинике впервые. Очень понра...          1
# 9996  В течении 2 лет обращалась с температурой, сда...          0
# 9997  Анна Аштовотовна не просто специалист от бога,...          1
# 9998  В течение 2 месяцев не могли установить онколо...          0
# 9999  Я лежала в Ганнушкино в 2010 году. Легла сама,...          1
#
#                                       processed_reviews
# 0     огромный благодарность анне геннадиевич рябцев...
# 1     казахстан г алматы тща ходить серагема 2 3 год...
# 2     пусть немного странный хотеть выразить благода...
# 3     очень понравиться отношение пациент предельный...
# 4     лично считать бесплатный консультация вполне с...
# ...                                                 ...
# 9995  02 февраль клиника впервые очень понравиться и...
# 9996  течение 2 год обращаться температура сдавать а...
# 9997  анна аштовотович просто специалист бог врач зо...
# 9998  течение 2 месяц мочь установить онкология 68 л...
# 9999  лежать ганнушкино 2010 год лечь жалеть персона...
#
# [10000 rows x 3 columns]

# %%
docs = df['processed_reviews'].tolist()

# %%
model = SentenceTransformer('all-MiniLM-L12-v2', device='mps')
embeddings = model.encode(docs, batch_size=256, show_progress_bar = True)
# Out:
# Batches:   0%|          | 0/40 [00:00<?, ?it/s]

# %%
np.save("healthcare_facilities_reviews_embeddings.npy", embeddings)

# %% [markdown]
# ## 2. Model Training

# %%
embeddings = np.load("../data/healthcare_facilities_reviews_embeddings.npy")

# %% [markdown]
# ### 2.1.1 BERTopic

# %%
umap_model = UMAP(
    n_neighbors = 15,
    n_components = 5,
    min_dist = 0.0,
    metric = 'cosine',
    low_memory = True
)           

hdbscan_model = HDBSCAN(
    min_cluster_size=30,
    metric="euclidean",
    cluster_selection_method="eom"
)

# %%
bertopic_model = BERTopic(
    language="multilingual", 
    umap_model = umap_model,
    hdbscan_model = hdbscan_model,
    calculate_probabilities=False)

# %%
topics, probs = bertopic_model.fit_transform(docs, embeddings)

# %%
bertopic_model.get_topic_info().head(5)
# Out:
#    Topic  Count                     Name  \
# 0     -1    661    -1_врач_весь_это_день
# 1      0   5705    0_врач_весь_очень_это
# 2      1    763    1_врач_весь_это_очень
# 3      2    701      2_год_весь_врач_это
# 4      3    381  3_весь_врач_это_сказать
#
#                                       Representation  \
# 0  [врач, весь, это, день, сказать, ребенок, отде...
# 1  [врач, весь, очень, это, клиника, спасибо, кот...
# 2  [врач, весь, это, очень, клиника, жизнь, сказа...
# 3  [год, весь, врач, это, отделение, ребенок, ден...
# 4  [весь, врач, это, сказать, отделение, день, ре...
#
#                                  Representative_Docs
# 0  [16082010 утро жк дать направление 17 роддом т...
# 1  [клиника несколько работать настоящий врач лор...
# 2  [хотеть рассказать мнение клиника жена ходить ...
# 3  [02 октябрь 2012 родить второй роддом долго вы...
# 4  [начаться рождение малыш родиться новогодний п...

# %%
original_reviews = df["reviews"]
bert_topic_to_reviews = defaultdict(list)

for review, topic_id in zip(original_reviews, topics):
    bert_topic_to_reviews[topic_id] = review

# %% [markdown]
# ### 2.1.2 LDA

# %%
tokenised_reviews = [doc.split() for doc in docs]

dictionary = corpora.Dictionary(tokenised_reviews)

corpus = [dictionary.doc2bow(token) for token in tokenised_reviews]

# %%
num_topics_list = [15, 20, 25]
alpha_list = ['auto', 0.1, 0.5]
eta_list = ['auto', 0.1, 0.5]

best_model = None
best_coherence = -1

for num_topics, alpha, eta in itertools.product(num_topics_list, alpha_list, eta_list):
    lda = LdaModel(corpus=corpus, id2word=dictionary, 
                   num_topics=num_topics, alpha=alpha, eta=eta,
                   passes=10, random_state=42)
    coherence_model = CoherenceModel(model=lda, texts=tokenised_reviews, dictionary=dictionary, coherence='c_v')
    coherence = coherence_model.get_coherence()
    print(num_topics, alpha, eta, coherence)
    if coherence > best_coherence:
        best_coherence = coherence
        best_model = lda
# Out:
# 15 auto auto 0.5817964287146807
# 15 auto 0.1 0.6071915891813656
# 15 auto 0.5 0.4472889903750628
# 15 0.1 auto 0.5548821777106281
# 15 0.1 0.1 0.5836439748020633
# 15 0.1 0.5 0.41348413878542495
# 15 0.5 auto 0.43803382406859337
# 15 0.5 0.1 0.5364469815489162
# 15 0.5 0.5 0.4115416814989305
# 20 auto auto 0.5524783112841479
# 20 auto 0.1 0.6245479925888927
# 20 auto 0.5 0.4362463992209976
# 20 0.1 auto 0.5310420353733213
# 20 0.1 0.1 0.6130880671535606
# 20 0.1 0.5 0.4161509829454147
# 20 0.5 auto 0.4336442403029899
# 20 0.5 0.1 0.5792614826602439
# 20 0.5 0.5 0.4081023904743737
# 25 auto auto 0.5743170953519126
# 25 auto 0.1 0.6320281777237766
# 25 auto 0.5 0.4468980398027822
# 25 0.1 auto 0.5594378551952452
# 25 0.1 0.1 0.6105779544744095
# 25 0.1 0.5 0.39425274955452994
# 25 0.5 auto 0.39503456112659835
# 25 0.5 0.1 0.5698478890446387
# 25 0.5 0.5 0.5099118134746553

# %%
num_topics = 20

lda_model = LdaModel(
    corpus = corpus,
    id2word = dictionary,
    num_topics = num_topics,
    random_state = 42,
    passes = 10,
    alpha = 0.5,
    per_word_topics = True,
    eta = 0.1
)

# %%
lda_topics = []

for bow in corpus:
    topic_probs = lda_model.get_document_topics(bow)
    dominant_topic = max(topic_probs, key=lambda x: x[1])[0]
    lda_topics.append(dominant_topic)

# %%
lda_topic_to_reviews = defaultdict(list)

for review, topic_id in zip(original_reviews, lda_topics):
    lda_topic_to_reviews[topic_id].append(review)

for topic, reviews in lda_topic_to_reviews.items():
    print(f"Topic {topic}: {len(lda_topic_to_reviews[topic])} docs")
# Out:
# Topic 3: 2507 docs
# Topic 13: 2902 docs
# Topic 1: 1621 docs
# Topic 4: 2161 docs
# Topic 7: 208 docs
# Topic 19: 256 docs
# Topic 18: 188 docs
# Topic 15: 119 docs
# Topic 17: 28 docs
# Topic 6: 7 docs
# Topic 12: 3 docs

# %% [markdown]
# ### 2.2 Model Evaluation

# %%
coherence_model = CoherenceModel(
    model=lda_model, 
    texts=tokenised_reviews, 
    dictionary=dictionary, 
    coherence='c_v')

coherence_score = coherence_model.get_coherence()
print("LDA Coherence Score:", coherence_score)
# Out:
# LDA Coherence Score: 0.5792614826602439

# %%
topic_words = [[w for w,_ in bertopic_model.get_topic(t)] 
                for t in bertopic_model.get_topic_info().Topic if t != -1]

coherence_model = CoherenceModel(
    topics=topic_words,
    texts=tokenised_reviews,
    dictionary=dictionary, 
    coherence='c_v'
)

coherence_score = coherence_model.get_coherence()
print("BERTopic Coherence Score:", coherence_score)
# Out:
# BERTopic Coherence Score: 0.3775813239971198

# %% [markdown]
# ## 2.3 Model Selection & Topic ID Assignment

# %%
df['topic_id'] = lda_topics

# %%
df.head()
# Out:
#                                              reviews  sentiment  \
# 0  Огромная благодарность Анне Геннадьевне Рябцев...          1
# 1  Казахстан, г. Алматы, тёща ходила на Серагем 2...          0
# 2  Пусть будет немного странно, но хотела бы выра...          1
# 3  Мне очень понравилось отношение к пациенту. Пр...          1
# 4  Ну, лично я считаю, что для бесплатной консуль...          1
#
#                                    processed_reviews  topic_id
# 0  огромный благодарность анне геннадиевич рябцев...         3
# 1  казахстан г алматы тща ходить серагема 2 3 год...        13
# 2  пусть немного странный хотеть выразить благода...         3
# 3  очень понравиться отношение пациент предельный...         3
# 4  лично считать бесплатный консультация вполне с...        13

# %% [markdown]
# ## 3 Topic Summarisation

# %% [markdown]
# ### 3.1 Representatives Selection

# %%
lda_topics_probs = []

for bow in corpus:
    topic_probs = lda_model.get_document_topics(bow)
    dominant_topic_prob = max(topic_probs, key=lambda x: x[1])[1]
    lda_topics_probs.append(dominant_topic_prob)

# %%
df["topic_confidence"] = lda_topics_probs

# %%
df.head(10)
# Out:
#                                              reviews  sentiment  \
# 0  Огромная благодарность Анне Геннадьевне Рябцев...          1
# 1  Казахстан, г. Алматы, тёща ходила на Серагем 2...          0
# 2  Пусть будет немного странно, но хотела бы выра...          1
# 3  Мне очень понравилось отношение к пациенту. Пр...          1
# 4  Ну, лично я считаю, что для бесплатной консуль...          1
# 5  Первый раз попали к педиатру Чеглаковой Евгени...          1
# 6  Сейчас столько возможностей похудеть, давно эт...          1
# 7  Отношение неплохое, но анестезиолог, например,...          0
# 8  Ну, начнём.\nЗначит сегодня 26.08.2015 год.\nР...          0
# 9  Во время беременности мне необходимо было сдат...          1
#
#                                    processed_reviews  topic_id  \
# 0  огромный благодарность анне геннадиевич рябцев...         3
# 1  казахстан г алматы тща ходить серагема 2 3 год...        13
# 2  пусть немного странный хотеть выразить благода...         3
# 3  очень понравиться отношение пациент предельный...         3
# 4  лично считать бесплатный консультация вполне с...        13
# 5  первый попасть педиатр чеглаков евгения валери...         3
# 6  столько возможность похудеть давно это переста...        13
# 7  отношение неплохой анестезиолог например прийт...        13
# 8  начнм значить сегодня 26082015 год решить позв...         1
# 9  время беременность необходимый сдать обязатель...         4
#
#    topic_confidence
# 0          0.452537
# 1          0.337037
# 2          0.468332
# 3          0.249642
# 4          0.394573
# 5          0.303528
# 6          0.301174
# 7          0.371662
# 8          0.651210
# 9          0.285010

# %%
top_docs_per_topic = df.groupby('topic_id').apply(
    lambda x: x.nlargest(min(5, len(x)), 'topic_confidence'), include_groups=False
).reset_index(drop=False)

# %%
top_docs_per_topic
# Out:
#     topic_id  level_1                                            reviews  \
# 0          1     3214  Сегодня по направлению Вашего врача пришел сда...
# 1          1     6844  В понедельник, в терминале взяли талончик на с...
# 2          1     4314  На сайте этой аптеки уже давно "висят" объявле...
# 3          1     2543  Сегодня получила незабываемые ощущения от рабо...
# 4          1     6474  Хамское отношение в этой поликлиннике начинает...
# 5          3     4819  Добрый день! Хочу выразить огромную благодарно...
# 6          3     8827  Хочу выразить огромную благодарность травматол...
# 7          3     9271  Благодарю от всей души за высокий профессионал...
# 8          3     6323  Выражаю сердечную признательность коллективу о...
# 9          3     2538  Большое спасибо врачам 17 гор. Больницы. Лежал...
# 10         4     2061  Совсем недавно получила неожиданно позитивный ...
# 11         4     2913  Пару недель назад решила установить себе бреке...
# 12         4     5935  О Б-клинике я на форуме от одной девушки узнал...
# 13         4     3283  К врачу Роберту Вагановичу Мамиконяну приехала...
# 14         4     6331  Здравствуйте! А вот мы например тоже очень дав...
# 15         6      971  Опять подошел День защиты детей. И никто их не...
# 16         6     1244  1. На этот сайт меня привёл гугл.\n"Мы обжалов...
# 17         6      579  Верните запись. Почему нельзя брать талончик к...
# 18         6     4943  В субботний день (14 марта 2012) вызывали врач...
# 19         6     6479  Нашу Детскую поликлинику № 53 (филиал № 2 ДГП ...
# 20         7     4414  Спасибо акушеркам, Тане и Вике и всем остальны...
# 21         7     5447  Родила 8 сентября 2010 г. Хороший роддом, вним...
# 22         7     2540  Добрый день. 8 ноября 2010 г. родила дочку, ро...
# 23         7     4430  Собираюсь рожать третьего ребенка в этом роддо...
# 24         7     2398  Мне очень понравился Люберецкий роддом! Рожала...
# 25        12     9922  Вceми любимaя вocтoчнaя мeдицинa. Вceм дaвнo и...
# 26        12     2098  После неоднократной сдачи крови на плазму на с...
# 27        12      674  Я в шоке от этого обслуживания. Я молилась, чт...
# 28        13     3571  Здравствуйте! У меня была беременность 11,5 не...
# 29        13     3863  Итак начну свой рассказ, 14 апреля 2015 года я...
# 30        13     1107  Находились с 15.02 по 18.02.2010 г. в инфекцио...
# 31        13     7699  Находились с 15.02 по 18.02.2010 г. в инфекцио...
# 32        13     1448  Здравствуйте!\nПопали в больницу 3 марта 2013 ...
# 33        15      604  Обращался по страховке в июле 2015 года в данн...
# 34        15     5176  Пришел, два зуба болит. Находится на Путевом п...
# 35        15      232  Доктор действительно внимательный, всегда стар...
# 36        15      953  Я 6 лет лечила зубы у Михайловой Е. В. Думала,...
# 37        15     4201  Испортили зуб, ещё и развести хотели!\nИзначал...
# 38        17     8644  Купила на днях контактные линзы в салоне ТЦ Тр...
# 41          0  прийти делать корригирующими очко тц витте мол...
# 42          0  уважаемый потенциальный покупатель компания пр...
# 43          1  спортивный травма начаться жуткий боль спина 3...
# 44          0  оперироваться данный клиника диагноз каверном ...
# 45          0  ребенок 5 год поступить больница перелом нижни...
# 46          1  благодаря операция хирург чувствовать моложе г...
# 47          1  сделать пластика москва гонин владислав анатол...
# 48          0  невозможный узнать состояние больной отделение...
# 49          0  вызвать врач дом телефон просто невозможный те...
# 50          0  наш друг вчера умереть реанимация перевести бо...
# 51          0  судебный заседание ночь подсунуть острый предм...
# 52          0  2 месяц назад реанимация 50 больница умереть н...
#
#     topic_confidence
# 0           0.811679
# 1           0.810256
# 2           0.788203
# 3           0.787075
# 4           0.786495
# 5           0.868307
# 6           0.867327
# 7           0.860578
# 8           0.854459
# 9           0.843483
# 10          0.831209
# 11          0.774088
# 12          0.771128
# 13          0.768155
# 14          0.766774
# 15          0.334698
# 16          0.311103
# 17          0.293936
# 18          0.264649
# 19          0.250576
# 20          0.659646
# 21          0.639286
# 22          0.601235
# 23          0.595660
# 24          0.560946
# 25          0.645721
# 26          0.359251
# 27          0.210443
# 28          0.929968
# 29          0.926276
# 30          0.920876
# 31          0.914202
# 32          0.906539
# 33          0.551839
# 34          0.529912
# 35          0.525875
# 36          0.514012
# 37          0.508172
# 38          0.545116
# 39          0.439287
# 40          0.382402
# 41          0.374308
# 42          0.374245
# 43          0.657042
# 44          0.567629
# 45          0.548174
# 46          0.541227
# 47          0.530688
# 48          0.695866
# 49          0.663946
# 50          0.657888
# 51          0.621662
# 52          0.568452

# %%
top_docs_per_topic.drop(columns=['level_1'])
# Out:
#     topic_id                                            reviews  sentiment  \
# 0          1  Сегодня по направлению Вашего врача пришел сда...          0
# 1          1  В понедельник, в терминале взяли талончик на с...          0
# 2          1  На сайте этой аптеки уже давно "висят" объявле...          0
# 3          1  Сегодня получила незабываемые ощущения от рабо...          0
# 4          1  Хамское отношение в этой поликлиннике начинает...          0
# 5          3  Добрый день! Хочу выразить огромную благодарно...          1
# 6          3  Хочу выразить огромную благодарность травматол...          1
# 7          3  Благодарю от всей души за высокий профессионал...          1
# 8          3  Выражаю сердечную признательность коллективу о...          1
# 9          3  Большое спасибо врачам 17 гор. Больницы. Лежал...          1
# 10         4  Совсем недавно получила неожиданно позитивный ...          1
# 11         4  Пару недель назад решила установить себе бреке...          1
# 12         4  О Б-клинике я на форуме от одной девушки узнал...          1
# 13         4  К врачу Роберту Вагановичу Мамиконяну приехала...          1
# 14         4  Здравствуйте! А вот мы например тоже очень дав...          1
# 15         6  Опять подошел День защиты детей. И никто их не...          0
# 16         6  1. На этот сайт меня привёл гугл.\n"Мы обжалов...          0
# 17         6  Верните запись. Почему нельзя брать талончик к...          0
# 18         6  В субботний день (14 марта 2012) вызывали врач...          0
# 19         6  Нашу Детскую поликлинику № 53 (филиал № 2 ДГП ...          1
# 20         7  Спасибо акушеркам, Тане и Вике и всем остальны...          1
# 21         7  Родила 8 сентября 2010 г. Хороший роддом, вним...          1
# 22         7  Добрый день. 8 ноября 2010 г. родила дочку, ро...          1
# 41          0.374308
# 42          0.374245
# 43          0.657042
# 44          0.567629
# 45          0.548174
# 46          0.541227
# 47          0.530688
# 48          0.695866
# 49          0.663946
# 50          0.657888
# 51          0.621662
# 52          0.568452

# %% [markdown]
# ### 3.2 Translation

# %%
model_name = 'Helsinki-NLP/opus-mt-ru-en'
tokeniser = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

device = "cpu"
model.to(device)
# Out:
# MarianMTModel(
#   (model): MarianModel(
#     (shared): Embedding(62518, 512, padding_idx=62517)
#     (encoder): MarianEncoder(
#       (embed_tokens): Embedding(62518, 512, padding_idx=62517)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0-5): 6 x MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): SiLU()
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (decoder): MarianDecoder(
#       (embed_tokens): Embedding(62518, 512, padding_idx=62517)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(512, 512)
#       (layers): ModuleList(
#         (0-5): 6 x MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (activation_fn): SiLU()
#           (self_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=512, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (lm_head): Linear(in_features=512, out_features=62518, bias=False)
# )

# %%
def translate_text(texts, batch_size = 10):
    translations =[]
    for i in tqdm(range(0, len(texts), batch_size), desc = "translating"):
        batch = texts[i:i+batch_size]
        inputs = tokeniser(batch, return_tensors = "pt", padding = True, truncation = True).to(device)
        with torch.no_grad():
            translated = model.generate(**inputs)
        decoded = [tokeniser.decode(t, skip_special_tokens = True) for t in translated]
        translations.extend(decoded)
    return translations

# %%
reviews_list = top_docs_per_topic['reviews'].tolist()
translated_reviews = translate_text(reviews_list, batch_size = 10)
# Out:
# translating: 100%|████████████████████████████████| 6/6 [04:01<00:00, 40.27s/it]

# %%
top_docs_per_topic['translated_reviews'] = translated_reviews

# %%
top_docs_per_topic.to_csv("translated_reviews_by_topic.csv", index=False)

# %% [markdown]
# ### 3.3 Summarisation

# %%
summariser = pipeline("summarization", model="sshleifer/distilbart-cnn-12-6")

topic_summaries = []

for topic_id, group in tqdm(top_docs_per_topic.groupby('topic_id'), desc="Summarising topics"):
    
    reviews_text = " ".join(group['translated_reviews'].tolist())
    text_to_summarise = reviews_text
    
    summary = summariser(
        text_to_summarise,
        max_length=100,
        min_length=30,
        do_sample=False
    )[0]['summary_text']

    topic_summaries.append({
        "topic_id": topic_id,
        "summary": summary,
        "representative_reviews": reviews_text
    })


summaries_df = pd.DataFrame(topic_summaries)

print(summaries_df.head())
# Out:
# Device set to use mps:0
# Summarising topics: 100%|███████████████████████| 10/10 [00:11<00:00,  1.20s/it]
#    topic_id                                            summary  \
# 0         1   A patient was forced to pay 400 rubles to pay...
# 1         3   I am ashamed of the professionalism of the do...
# 2         4   I've cured a few teeth from Dr. Kurilov Evgen...
# 3         7   6 r/d gave birth to a 17-year-old house in Lu...
# 4        13   On November 22, 2015, a gynaecologist said th...
#
#                               representative_reviews
# 0  Today, at your doctor's address, he came to do...
# 1  Good afternoon, I wish to express my great gra...
# 2  I've just had an unexpected positive experienc...
# 3  Thanks to midwives, Tane and Vique, and all ot...
# 4  Hello, I had a pregnancy for 11.5 weeks. On No...

# %%
topic_stats = df.groupby('topic_id').agg(
    count = ('reviews', 'count'),
    positive = ('sentiment', lambda x: (x == 1).sum()),
    negative = ('sentiment', lambda x : (x == 0).sum())).reset_index()

# %%
topic_stats
# Out:
#    topic_id  count  positive  negative
# 0         1   1621       266      1355
# 1         3   2507      2455        52
# 2         4   2161      1832       329
# 3         7    208       194        14
# 4        13   2902       894      2008
# 5        15    119        39        80
# 6        17     28        16        12
# 7        18    188       121        67
# 8        19    256        23       233
# 9        99     10         2         8

# %%
final_df = summaries_df.merge(topic_stats, on='topic_id', how='left')

# %%
final_df
# Out:
#    topic_id                                            summary  \
# 0         1   A patient was forced to pay 400 rubles to pay...
# 1         3   I am ashamed of the professionalism of the do...
# 2         4   I've cured a few teeth from Dr. Kurilov Evgen...
# 3         7   6 r/d gave birth to a 17-year-old house in Lu...
# 4        13   On November 22, 2015, a gynaecologist said th...
# 5        15   Vladimir Pood. came with Caries in two teeth,...
# 6        17   The T.C. Triumphal salon is not recommended f...
# 7        18   After a sports injury, terrible back pains be...
# 8        19   A friend of ours died yesterday in ICU, and h...
# 9        99   It's Child Protection Day again, and no one h...
#
#                               representative_reviews  count  positive  \
# 0  Today, at your doctor's address, he came to do...   1621       266
# 1  Good afternoon, I wish to express my great gra...   2507      2455
# 2  I've just had an unexpected positive experienc...   2161      1832
# 3  Thanks to midwives, Tane and Vique, and all ot...    208       194
# 4  Hello, I had a pregnancy for 11.5 weeks. On No...   2902       894
# 5  Yeah, it's all beautiful and neat, the patient...    119        39
# 6  I bought contact lenses at the T.C. Triumphal ...     28        16
# 7  After a sports injury, terrible back pains beg...    188       121
# 8  There's no way to know the state of the patien...    256        23
# 9  It's Child Protection Day again, and no one ha...     10         2
#
#    negative
# 0      1355
# 1        52
# 2       329
# 3        14
# 4      2008
# 5        80
# 6        12
# 7        67
# 8       233
# 9         8

# %%
final_df.to_csv("../data/summaries.csv", index=False)
